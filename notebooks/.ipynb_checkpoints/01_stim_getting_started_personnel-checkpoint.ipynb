# %% [markdown]
# # TP Stim — prise en main
#
# ## 1. Premier circuit Stim
#
# ## 2. Mesures brutes
#
# ## 3. Détecteurs
#
# ## 4. Surface code d=3
#
# ## 5. Sampling des syndromes et observables
#
# ## 6. Detector Error Model
#
# ## 7. Traduction DEM vers H, A, p
